# %%
"""
Amplitude Estimation Benchmark Program via Phase Estimation - Qiskit
"""

import copy
import sys
import time

import numpy as np
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister

sys.path[1:1] = ["_common", "_common/qiskit", "quantum-fourier-transform/qiskit"]
sys.path[1:1] = ["../../_common", "../../_common/qiskit", "../../quantum-fourier-transform/qiskit"]
import execute as ex
import metrics as metrics
from qft_benchmark import inv_qft_gate

from qiskit import Aer, transpile
from qiskit.tools.visualization import plot_histogram, plot_state_city
import qiskit.quantum_info as qi

# %%
# Benchmark Name
benchmark_name = "Amplitude Estimation"

np.random.seed(0)

verbose = False

# saved subcircuits circuits for printing
A_ = None
Q_ = None
cQ_ = None
QC_ = None
QFTI_ = None

# %% [markdown]
# # Circuit Definition

# %%
def AmplitudeEstimation(num_state_qubits, num_counting_qubits, a, psi_zero=None, psi_one=None):

    num_qubits = num_state_qubits + 1 + num_counting_qubits
    
    qr_state = QuantumRegister(num_state_qubits+1)
    qr_counting = QuantumRegister(num_counting_qubits)
    cr = ClassicalRegister(num_counting_qubits)
    qc = QuantumCircuit(qr_counting, qr_state, cr, name=f"qae-{num_qubits}-{a}")
    
    # create the Amplitude Generator circuit
    A = A_gen(num_state_qubits, a, psi_zero, psi_one)

    # create the Quantum Operator circuit and a controlled version of it
    cQ, Q = Ctrl_Q(num_state_qubits, A)
    
    # save small example subcircuits for visualization
    global A_, Q_, cQ_, QFTI_
    if (cQ_ and Q_) == None or num_state_qubits <= 6:
        if num_state_qubits < 9: cQ_ = cQ; Q_ = Q; A_ = A
    if QFTI_ == None or num_qubits <= 5:
        if num_qubits < 9: QFTI_ = inv_qft_gate(num_counting_qubits)

    # Prepare state from A, and counting qubits with H transform 
    qc.append(A, [qr_state[i] for i in range(num_state_qubits+1)])
    for i in range(num_counting_qubits):
        qc.h(qr_counting[i])
    
    repeat = 1
    for j in reversed(range(num_counting_qubits)):
        for _ in range(repeat):
            qc.append(cQ, [qr_counting[j]] + [qr_state[l] for l in range(num_state_qubits+1)])
        repeat *= 2
    
    qc.barrier()

    # inverse quantum Fourier transform only on counting qubits
    qc.append(inv_qft_gate(num_counting_qubits), qr_counting)

    qc.barrier()

    # measure counting qubits
    qc.measure([qr_counting[m] for m in range(num_counting_qubits)], list(range(num_counting_qubits)))

    # save smaller circuit example for display
    global QC_
    if QC_ == None or num_qubits <= 5:
        if num_qubits < 9: QC_ = qc
    return qc

# %% [markdown]
# # Construct A operator that takes |0>_{n+1} to sqrt(1-a) |psi_0>|0> + sqrt(a) |psi_1>|1>

# %%
def A_gen(num_state_qubits, a, psi_zero=None, psi_one=None):

    if psi_zero==None:
        psi_zero = '0'*num_state_qubits
    if psi_one==None:
        psi_one = '1'*num_state_qubits
        
    theta = 2 * np.arcsin(np.sqrt(a))
    # Let the objective be qubit index n; state is on qubits 0 through n-1
    qc_A = QuantumCircuit(num_state_qubits+1, name=f"A")
    
    # takes state to |0>_{n} (sqrt(1-a) |0> + sqrt(a) |1>)
    qc_A.ry(theta, num_state_qubits)
    
    # takes state to sqrt(1-a) |psi_0>|0> + sqrt(a) |0>_{n}|1>
    qc_A.x(num_state_qubits)
    for i in range(num_state_qubits):
        if psi_zero[i]=='1':
            qc_A.cnot(num_state_qubits,i)
    qc_A.x(num_state_qubits)
    
    # takes state to sqrt(1-a) |psi_0>|0> + sqrt(a) |psi_1>|1>
    for i in range(num_state_qubits):
        if psi_one[i]=='1':
            qc_A.cnot(num_state_qubits,i)
    
    return qc_A

# %% [markdown]
# # Construct the grover-like operator and a controlled version of it

# %%
def Ctrl_Q(num_state_qubits, A_circ):

    # index n is the objective qubit, and indexes 0 through n-1 are state qubits
    qc = QuantumCircuit(num_state_qubits+1, name=f"Q")
    
    temp_A = copy.copy(A_circ)
    A_gate = temp_A.to_gate()
    A_gate_inv = temp_A.inverse().to_gate()
    
    ### Each cycle in Q applies in order: -S_chi, A_circ_inverse, S_0, A_circ 
    # -S_chi
    qc.x(num_state_qubits)
    qc.z(num_state_qubits)
    qc.x(num_state_qubits)
        
    # A_circ_inverse
    qc.append(A_gate_inv, [i for i in range(num_state_qubits+1)])
        
    # S_0
    for i in range(num_state_qubits+1):
        qc.x(i)
    qc.h(num_state_qubits)
    
    qc.mcx([x for x in range(num_state_qubits)], num_state_qubits)
    
    qc.h(num_state_qubits)
    for i in range(num_state_qubits+1):
        qc.x(i)
        
    # A_circ
    qc.append(A_gate, [i for i in range(num_state_qubits+1)])
    
    # Create a gate out of the Q operator
    qc.to_gate(label='Q')
    
    # and also a controlled version of it
    Ctrl_Q_ = qc.control(1)
    
    # and return both
    return Ctrl_Q_, qc

# %% [markdown]
# Analyze and print measured results

# %% [markdown]
# # Expected result is always the secret_int (which encodes alpha), so fidelity calc is simple

# %%
def analyze_and_print_result(qc, result, num_counting_qubits, s_int, num_shots):
    
    # get results as measured counts
    counts = result.get_counts(qc) 
        
    # calculate expected output histogram
    a = a_from_s_int(s_int, num_counting_qubits)
    correct_dist = a_to_bitstring(a, num_counting_qubits)  

    # generate thermal_dist for polarization calculation
    thermal_dist = metrics.uniform_dist(num_counting_qubits)
    
    # convert counts, expectation, and thermal_dist to app form for visibility
    # app form of correct distribution is measuring amplitude a 100% of the time
    app_counts = bitstring_to_a(counts, num_counting_qubits)
    app_correct_dist = {a: 1.0}
    app_thermal_dist = bitstring_to_a(thermal_dist, num_counting_qubits)

    if verbose:
        print(f"For amplitude {a}, expected: {correct_dist} measured: {counts}")
        print(f"   ... For amplitude {a} thermal_dist: {thermal_dist}")
        print(f"For amplitude {a}, app expected: {app_correct_dist} measured: {app_counts}")
        print(f"   ... For amplitude {a} app_thermal_dist: {app_thermal_dist}")

    # use polarization fidelity with rescaling
    fidelity = metrics.polarization_fidelity(counts, correct_dist, thermal_dist)
    #fidelity = metrics.polarization_fidelity(app_counts, app_correct_dist, app_thermal_dist)
    
    hf_fidelity = metrics.hellinger_fidelity_with_expected(counts, correct_dist)

    if verbose: print(f"  ... fidelity: {fidelity}  hf_fidelity: {hf_fidelity}")
    
    return counts, fidelity

# %%
def a_to_bitstring(a, num_counting_qubits):
    m = num_counting_qubits

    # solution 1
    num1 = round(np.arcsin(np.sqrt(a)) / np.pi * 2**m)
    num2 = round( (np.pi - np.arcsin(np.sqrt(a))) / np.pi * 2**m)
    if num1 != num2 and num2 < 2**m and num1 < 2**m:
        counts = {format(num1, "0"+str(m)+"b"): 0.5, format(num2, "0"+str(m)+"b"): 0.5}
    else:
        counts = {format(num1, "0"+str(m)+"b"): 1}
    return counts

# %%
def bitstring_to_a(counts, num_counting_qubits):
    est_counts = {}
    m = num_counting_qubits
    precision = int(num_counting_qubits / (np.log2(10))) + 2
    for key in counts.keys():
        r = counts[key]
        num = int(key,2) / (2**m)
        a_est = round((np.sin(np.pi * num) )** 2, precision)
        if a_est not in est_counts.keys():
            est_counts[a_est] = 0
        est_counts[a_est] += r
    return est_counts

# %%
def a_from_s_int(s_int, num_counting_qubits):
    theta = s_int * np.pi / (2**num_counting_qubits)
    precision = int(num_counting_qubits / (np.log2(10))) + 2
    a = round(np.sin(theta)**2, precision)
    return a

# %% [markdown]
# # Benchmark Loop
#
# Because circuit size grows significantly with num_qubits
#
# limit the max_qubits here ...

# %%
MAX_QUBITS=8

# %% [markdown]
# # Execute program with default parameters

# %% [markdown]
# # Qasm Simulator

# %%
def run(min_qubits=3, max_qubits=8, skip_qubits=1, max_circuits=3, num_shots=100,
        num_state_qubits=1, # default, not exposed to users
        backend_id='qasm_simulator', provider_backend=None,
        hub="ibm-q", group="open", project="main", exec_options=None,
        context=None):

    print(f"{benchmark_name} Benchmark Program - Qiskit")

    # Clamp the maximum number of qubits
    if max_qubits > MAX_QUBITS:
        print(f"INFO: {benchmark_name} benchmark is limited to a maximum of {MAX_QUBITS} qubits.")
        max_qubits = MAX_QUBITS
        
    # validate parameters (smallest circuit is 3 qubits)
    num_state_qubits = max(1, num_state_qubits)
    if max_qubits < num_state_qubits + 2:
        print(f"ERROR: AE Benchmark needs at least {num_state_qubits + 2} qubits to run")
        return
    min_qubits = max(max(3, min_qubits), num_state_qubits + 2)
    skip_qubits = max(1, skip_qubits)
    #print(f"min, max, state = {min_qubits} {max_qubits} {num_state_qubits}")

    # create context identifier
    if context is None: context = f"{benchmark_name} Benchmark"
    
    ##########
    
    # Initialize metrics module
    metrics.init_metrics()
     # Define custom result handler
    def execution_handler(qc, result, num_qubits, s_int, num_shots):

        # determine fidelity of result set
        num_counting_qubits = int(num_qubits) - num_state_qubits - 1
        counts, fidelity = analyze_and_print_result(qc, result, num_counting_qubits, int(s_int), num_shots)
        metrics.store_metric(num_qubits, s_int, 'fidelity', fidelity)

    # Initialize execution module using the execution result handler above and specified backend_id
    ex.init_execution(execution_handler)
    ex.set_execution_target(backend_id, provider_backend=provider_backend,
            hub=hub, group=group, project=project, exec_options=exec_options,
            context=context)

    ##########
    
    # Execute Benchmark Program N times for multiple circuit sizes
    # Accumulate metrics asynchronously as circuits complete
    for num_qubits in range(min_qubits, max_qubits + 1, skip_qubits):

        # reset random seed
        np.random.seed(0)
        
        # as circuit width grows, the number of counting qubits is increased
        num_counting_qubits = num_qubits - num_state_qubits - 1

        # determine number of circuits to execute for this group
        num_circuits = min(2 ** (num_counting_qubits), max_circuits)
        
        print(f"************\nExecuting [{num_circuits}] circuits with num_qubits = {num_qubits}")
        if verbose:
            print(f"              with num_state_qubits = {num_state_qubits}  num_counting_qubits = {num_counting_qubits}")
        
        # determine range of secret strings to loop over
        if 2**(num_counting_qubits) <= max_circuits:
            s_range = list(range(num_circuits))
        else:
            s_range = np.random.choice(2**(num_counting_qubits), num_circuits, False)
        
        # loop over limited # of secret strings for this
        for s_int in s_range:
            # create the circuit for given qubit size and secret string, store time metric
            ts = time.time()

            a_ = a_from_s_int(s_int, num_counting_qubits)

            qc = AmplitudeEstimation(num_state_qubits, num_counting_qubits, a_)
            metrics.store_metric(num_qubits, s_int, 'create_time', time.time() - ts)

            # collapse the 3 sub-circuit levels used in this benchmark (for qiskit)
            qc2 = qc.decompose().decompose().decompose()
            
            # submit circuit for execution on target (simulator, cloud simulator, or hardware)
            ex.submit_circuit(qc2, num_qubits, s_int, num_shots)

        # Wait for some active circuits to complete; report metrics when groups complete
        ex.throttle_execution(metrics.finalize_group)

    # Wait for all active circuits to complete; report metrics when groups complete
    ex.finalize_execution(metrics.finalize_group)

# %% [markdown]
# # print a sample circuit

# %% [markdown]
# # if main, execute method

# %%
if __name__ == '__main__': run()
# Out:
# Amplitude Estimation Benchmark Program - Qiskit
# ... execution starting at Nov 07, 2023 10:50:10 UTC
# ************
# Executing [2] circuits with num_qubits = 3
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 72, 0.422
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 58, 0.387, 29.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.024, 0.983, 0.007 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.91, 0.82
#
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 208, 0.432
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 165, 0.398, 84.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.044, 2.824, 0.019 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.848, 0.728
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 479, 0.436
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 375, 0.404, 192.667
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.039, 6.306, 0.036 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.653, 0.538
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 1017, 0.438
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 836, 0.407, 426.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.121, 11.975, 0.113 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.376, 0.303
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 2086, 0.439
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 1701, 0.408, 868.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.204, 17.978, 0.611 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.166, 0.111
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 4214, 0.44
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 3417, 0.409, 1744.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.535, 11.179, 1.102 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.081, 0.052
#
# ... execution complete at Nov 07, 2023 10:51:07 UTC in 57.344 secs

# %%
    print("Sample Circuit:"); print(QC_ if QC_ != None else "  ... too large!")
    print("\nControlled Quantum Operator 'cQ' ="); print(cQ_ if cQ_ != None else " ... too large!")
    print("\nQuantum Operator 'Q' ="); print(Q_ if Q_ != None else " ... too large!")
    print("\nAmplitude Generator 'A' ="); print(A_ if A_ != None else " ... too large!")
    print("\nInverse QFT Circuit ="); print(QFTI_ if QC_ != None else "  ... too large!")

    # Plot metrics for all circuit sizes
    metrics.plot_metrics(f"Benchmark Results - {benchmark_name} - Qiskit")
# Out:
# Sample Circuit:
#         ┌───┐                         ┌──────┐┌──────┐┌──────┐┌──────┐ ░ »
# q187_0: ┤ H ├─────────────────────────┤0     ├┤0     ├┤0     ├┤0     ├─░─»
#         ├───┤         ┌──────┐┌──────┐│      ││      ││      ││      │ ░ »
# q187_1: ┤ H ├─────────┤0     ├┤0     ├┤      ├┤      ├┤      ├┤      ├─░─»
#         ├───┤ ┌──────┐│      ││      ││      ││      ││      ││      │ ░ »
# q187_2: ┤ H ├─┤0     ├┤      ├┤      ├┤  c_Q ├┤  c_Q ├┤  c_Q ├┤  c_Q ├─░─»
#         ├───┴┐│      ││  c_Q ││  c_Q ││      ││      ││      ││      │ ░ »
# q186_0: ┤0   ├┤1 c_Q ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├─░─»
#         │  A ││      ││      ││      ││      ││      ││      ││      │ ░ »
# q186_1: ┤1   ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├─░─»
#         └────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘ ░ »
#   c7: 3/═════════════════════════════════════════════════════════════════»
#                                                                          »
# «        ┌──────────┐ ░ ┌─┐
# «q187_0: ┤0         ├─░─┤M├──────
# «        │          │ ░ └╥┘┌─┐
# «q187_1: ┤1 inv_qft ├─░──╫─┤M├───
# «        │          │ ░  ║ └╥┘┌─┐
# «q187_2: ┤2         ├─░──╫──╫─┤M├
# «        └──────────┘ ░  ║  ║ └╥┘
# «q186_0: ─────────────░──╫──╫──╫─
# «                     ░  ║  ║  ║
# «q186_1: ─────────────░──╫──╫──╫─
# «                     ░  ║  ║  ║
# «  c7: 3/════════════════╩══╩══╩═
# «                        0  1  2
#
# Controlled Quantum Operator 'cQ' =
#
# q504: ──■───
#       ┌─┴──┐
#  q_0: ┤0   ├
#       │  Q │
#  q_1: ┤1   ├
#       └────┘
#
# Quantum Operator 'Q' =
#                     ┌───────┐┌───┐          ┌───┐     ┌────┐
# q_0: ───────────────┤0      ├┤ X ├───────■──┤ X ├─────┤0   ├
#      ┌───┐┌───┐┌───┐│  A_dg │├───┤┌───┐┌─┴─┐├───┤┌───┐│  A │
# q_1: ┤ X ├┤ Z ├┤ X ├┤1      ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤1   ├
#      └───┘└───┘└───┘└───────┘└───┘└───┘└───┘└───┘└───┘└────┘
#
# Amplitude Generator 'A' =
#                              ┌───┐
# q_0: ────────────────────────┤ X ├
#      ┌────────────┐┌───┐┌───┐└─┬─┘
# q_1: ┤ Ry(2.0624) ├┤ X ├┤ X ├──■──
#      └────────────┘└───┘└───┘
#
# Inverse QFT Circuit =
#         ┌───┐                         ░                   ░       ░
# q189_0: ┤ H ├─────■───────────■───────░───────────────────░───────░─
#         └───┘┌────┴─────┐     │       ░ ┌───┐             ░       ░
# q189_1: ─────┤ Rz(-π/2) ├─────┼───────░─┤ H ├─────■───────░───────░─
#              └──────────┘┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# q189_2: ─────────────────┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
#                          └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# # aer_simulator

# %%
def run(min_qubits=3, max_qubits=8, skip_qubits=1, max_circuits=3, num_shots=100,
        num_state_qubits=1, # default, not exposed to users
        backend_id='aer_simulator', provider_backend=None,
        hub="ibm-q", 
        group="open", project="main", exec_options=None,
        context=None):

    print(f"{benchmark_name} Benchmark Program - Qiskit")

    # Clamp the maximum number of qubits
    if max_qubits > MAX_QUBITS:
        print(f"INFO: {benchmark_name} benchmark is limited to a maximum of {MAX_QUBITS} qubits.")
        max_qubits = MAX_QUBITS
        
    # validate parameters (smallest circuit is 3 qubits)
    num_state_qubits = max(1, num_state_qubits)
    if max_qubits < num_state_qubits + 2:
        print(f"ERROR: AE Benchmark needs at least {num_state_qubits + 2} qubits to run")
        return
    min_qubits = max(max(3, min_qubits), num_state_qubits + 2)
    skip_qubits = max(1, skip_qubits)
    #print(f"min, max, state = {min_qubits} {max_qubits} {num_state_qubits}")

    # create context identifier
    if context is None: context = f"{benchmark_name} Benchmark"
    
    ##########
    
    # Initialize metrics module
    metrics.init_metrics()
     # Define custom result handler
    def execution_handler(qc, result, num_qubits, s_int, num_shots):

        # determine fidelity of result set
        num_counting_qubits = int(num_qubits) - num_state_qubits - 1
        counts, fidelity = analyze_and_print_result(qc, result, num_counting_qubits, int(s_int), num_shots)
        metrics.store_metric(num_qubits, s_int, 'fidelity', fidelity)

    # Initialize execution module using the execution result handler above and specified backend_id
    ex.init_execution(execution_handler)
    ex.set_execution_target(backend_id, provider_backend=provider_backend,
            hub=hub, group=group, project=project, exec_options=exec_options,
            context=context)

    ##########
    
    # Execute Benchmark Program N times for multiple circuit sizes
    # Accumulate metrics asynchronously as circuits complete
    for num_qubits in range(min_qubits, max_qubits + 1, skip_qubits):

        # reset random seed
        np.random.seed(0)
        
        # as circuit width grows, the number of counting qubits is increased
        num_counting_qubits = num_qubits - num_state_qubits - 1

        # determine number of circuits to execute for this group
        num_circuits = min(2 ** (num_counting_qubits), max_circuits)
        
        print(f"************\nExecuting [{num_circuits}] circuits with num_qubits = {num_qubits}")
        if verbose:
            print(f"              with num_state_qubits = {num_state_qubits}  num_counting_qubits = {num_counting_qubits}")
        
        # determine range of secret strings to loop over
        if 2**(num_counting_qubits) <= max_circuits:
            s_range = list(range(num_circuits))
        else:
            s_range = np.random.choice(2**(num_counting_qubits), num_circuits, False)
        
        # loop over limited # of secret strings for this
        for s_int in s_range:
            # create the circuit for given qubit size and secret string, store time metric
            ts = time.time()

            a_ = a_from_s_int(s_int, num_counting_qubits)

            qc = AmplitudeEstimation(num_state_qubits, num_counting_qubits, a_)
            metrics.store_metric(num_qubits, s_int, 'create_time', time.time() - ts)

            # collapse the 3 sub-circuit levels used in this benchmark (for qiskit)
            qc2 = qc.decompose().decompose().decompose()
            
            # submit circuit for execution on target (simulator, cloud simulator, or hardware)
            ex.submit_circuit(qc2, num_qubits, s_int, num_shots)

        # Wait for some active circuits to complete; report metrics when groups complete
        ex.throttle_execution(metrics.finalize_group)

    # Wait for all active circuits to complete; report metrics when groups complete
    ex.finalize_execution(metrics.finalize_group)

# %%
if __name__ == '__main__': run()
# Out:
# Amplitude Estimation Benchmark Program - Qiskit
# ... execution starting at Nov 07, 2023 10:51:12 UTC
# No credentials for IBMQ backend found. Using the simulator instead.
# ************
# Executing [2] circuits with num_qubits = 3
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 72, 0.422
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 58, 0.387, 29.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.014, 0.92, 0.011 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.915, 0.83
#
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 208, 0.432
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 165, 0.398, 84.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.029, 2.446, 0.008 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.806, 0.649
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 479, 0.436
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 375, 0.404, 192.667
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.03, 4.71, 0.035 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.626, 0.501
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 1017, 0.438
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 836, 0.407, 426.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.095, 9.085, 0.107 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.4, 0.331
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 2086, 0.439
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 1701, 0.408, 868.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.136, 23.251, 0.72 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.179, 0.125
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 4214, 0.44
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 3417, 0.409, 1744.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.589, 12.944, 1.319 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.084, 0.055
#
# ... execution complete at Nov 07, 2023 10:52:12 UTC in 59.412 secs

# %%
    print("Sample Circuit:"); print(QC_ if QC_ != None else "  ... too large!")
    print("\nControlled Quantum Operator 'cQ' ="); print(cQ_ if cQ_ != None else " ... too large!")
    print("\nQuantum Operator 'Q' ="); print(Q_ if Q_ != None else " ... too large!")
    print("\nAmplitude Generator 'A' ="); print(A_ if A_ != None else " ... too large!")
    print("\nInverse QFT Circuit ="); print(QFTI_ if QC_ != None else "  ... too large!")

    # Plot metrics for all circuit sizes
    metrics.plot_metrics(f"Benchmark Results - {benchmark_name} - Qiskit")
# Out:
# Sample Circuit:
#         ┌───┐                         ┌──────┐┌──────┐┌──────┐┌──────┐ ░ »
# q786_0: ┤ H ├─────────────────────────┤0     ├┤0     ├┤0     ├┤0     ├─░─»
#         ├───┤         ┌──────┐┌──────┐│      ││      ││      ││      │ ░ »
# q786_1: ┤ H ├─────────┤0     ├┤0     ├┤      ├┤      ├┤      ├┤      ├─░─»
#         ├───┤ ┌──────┐│      ││      ││      ││      ││      ││      │ ░ »
# q786_2: ┤ H ├─┤0     ├┤      ├┤      ├┤  c_Q ├┤  c_Q ├┤  c_Q ├┤  c_Q ├─░─»
#         ├───┴┐│      ││  c_Q ││  c_Q ││      ││      ││      ││      │ ░ »
# q785_0: ┤0   ├┤1 c_Q ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├─░─»
#         │  A ││      ││      ││      ││      ││      ││      ││      │ ░ »
# q785_1: ┤1   ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├─░─»
#         └────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘ ░ »
#  c24: 3/═════════════════════════════════════════════════════════════════»
#                                                                          »
# «        ┌──────────┐ ░ ┌─┐
# «q786_0: ┤0         ├─░─┤M├──────
# «        │          │ ░ └╥┘┌─┐
# «q786_1: ┤1 inv_qft ├─░──╫─┤M├───
# «        │          │ ░  ║ └╥┘┌─┐
# «q786_2: ┤2         ├─░──╫──╫─┤M├
# «        └──────────┘ ░  ║  ║ └╥┘
# «q785_0: ─────────────░──╫──╫──╫─
# «                     ░  ║  ║  ║
# «q785_1: ─────────────░──╫──╫──╫─
# «                     ░  ║  ║  ║
# « c24: 3/════════════════╩══╩══╩═
# «                        0  1  2
#
# Controlled Quantum Operator 'cQ' =
#
# q1103: ──■───
#        ┌─┴──┐
#   q_0: ┤0   ├
#        │  Q │
#   q_1: ┤1   ├
#        └────┘
#
# Quantum Operator 'Q' =
#                     ┌───────┐┌───┐          ┌───┐     ┌────┐
# q_0: ───────────────┤0      ├┤ X ├───────■──┤ X ├─────┤0   ├
#      ┌───┐┌───┐┌───┐│  A_dg │├───┤┌───┐┌─┴─┐├───┤┌───┐│  A │
# q_1: ┤ X ├┤ Z ├┤ X ├┤1      ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤1   ├
#      └───┘└───┘└───┘└───────┘└───┘└───┘└───┘└───┘└───┘└────┘
#
# Amplitude Generator 'A' =
#                              ┌───┐
# q_0: ────────────────────────┤ X ├
#      ┌────────────┐┌───┐┌───┐└─┬─┘
# q_1: ┤ Ry(2.0624) ├┤ X ├┤ X ├──■──
#      └────────────┘└───┘└───┘
#
# Inverse QFT Circuit =
#         ┌───┐                         ░                   ░       ░
# q788_0: ┤ H ├─────■───────────■───────░───────────────────░───────░─
#         └───┘┌────┴─────┐     │       ░ ┌───┐             ░       ░
# q788_1: ─────┤ Rz(-π/2) ├─────┼───────░─┤ H ├─────■───────░───────░─
#              └──────────┘┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# q788_2: ─────────────────┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
#                          └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# # aer_simulator_statevector

# %%
def run(min_qubits=3, max_qubits=8, skip_qubits=1, max_circuits=3, num_shots=100,
        num_state_qubits=1, # default, not exposed to users
        backend_id='aer_simulator_statevector', provider_backend=None,
        hub="ibm-q", 
        group="open", project="main", exec_options=None,
        context=None):

    print(f"{benchmark_name} Benchmark Program - Qiskit")

    # Clamp the maximum number of qubits
    if max_qubits > MAX_QUBITS:
        print(f"INFO: {benchmark_name} benchmark is limited to a maximum of {MAX_QUBITS} qubits.")
        max_qubits = MAX_QUBITS
        
    # validate parameters (smallest circuit is 3 qubits)
    num_state_qubits = max(1, num_state_qubits)
    if max_qubits < num_state_qubits + 2:
        print(f"ERROR: AE Benchmark needs at least {num_state_qubits + 2} qubits to run")
        return
    min_qubits = max(max(3, min_qubits), num_state_qubits + 2)
    skip_qubits = max(1, skip_qubits)
    #print(f"min, max, state = {min_qubits} {max_qubits} {num_state_qubits}")

    # create context identifier
    if context is None: context = f"{benchmark_name} Benchmark"
    
    ##########
    
    # Initialize metrics module
    metrics.init_metrics()
     # Define custom result handler
    def execution_handler(qc, result, num_qubits, s_int, num_shots):

        # determine fidelity of result set
        num_counting_qubits = int(num_qubits) - num_state_qubits - 1
        counts, fidelity = analyze_and_print_result(qc, result, num_counting_qubits, int(s_int), num_shots)
        metrics.store_metric(num_qubits, s_int, 'fidelity', fidelity)

    # Initialize execution module using the execution result handler above and specified backend_id
    ex.init_execution(execution_handler)
    ex.set_execution_target(backend_id, provider_backend=provider_backend,
            hub=hub, group=group, project=project, exec_options=exec_options,
            context=context)

    ##########
    
    # Execute Benchmark Program N times for multiple circuit sizes
    # Accumulate metrics asynchronously as circuits complete
    for num_qubits in range(min_qubits, max_qubits + 1, skip_qubits):

        # reset random seed
        np.random.seed(0)
        
        # as circuit width grows, the number of counting qubits is increased
        num_counting_qubits = num_qubits - num_state_qubits - 1

        # determine number of circuits to execute for this group
        num_circuits = min(2 ** (num_counting_qubits), max_circuits)
        
        print(f"************\nExecuting [{num_circuits}] circuits with num_qubits = {num_qubits}")
        if verbose:
            print(f"              with num_state_qubits = {num_state_qubits}  num_counting_qubits = {num_counting_qubits}")
        
        # determine range of secret strings to loop over
        if 2**(num_counting_qubits) <= max_circuits:
            s_range = list(range(num_circuits))
        else:
            s_range = np.random.choice(2**(num_counting_qubits), num_circuits, False)
        
        # loop over limited # of secret strings for this
        for s_int in s_range:
            # create the circuit for given qubit size and secret string, store time metric
            ts = time.time()

            a_ = a_from_s_int(s_int, num_counting_qubits)

            qc = AmplitudeEstimation(num_state_qubits, num_counting_qubits, a_)
            metrics.store_metric(num_qubits, s_int, 'create_time', time.time() - ts)

            # collapse the 3 sub-circuit levels used in this benchmark (for qiskit)
            qc2 = qc.decompose().decompose().decompose()
            
            # submit circuit for execution on target (simulator, cloud simulator, or hardware)
            ex.submit_circuit(qc2, num_qubits, s_int, num_shots)

        # Wait for some active circuits to complete; report metrics when groups complete
        ex.throttle_execution(metrics.finalize_group)

    # Wait for all active circuits to complete; report metrics when groups complete
    ex.finalize_execution(metrics.finalize_group)
if __name__ == '__main__': run()
# Out:
# Amplitude Estimation Benchmark Program - Qiskit
# ... execution starting at Nov 07, 2023 10:52:16 UTC
# No credentials for IBMQ backend found. Using the simulator instead.
# ************
# Executing [2] circuits with num_qubits = 3
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 72, 0.422
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 58, 0.387, 29.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.032, 0.721, 0.021 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.925, 0.85
#
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 208, 0.432
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 165, 0.398, 84.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.037, 2.51, 0.01 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.813, 0.677
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 479, 0.436
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 375, 0.404, 192.667
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.033, 4.319, 0.035 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.587, 0.449
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 1017, 0.438
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 836, 0.407, 426.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.044, 7.001, 0.073 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.382, 0.31
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 2086, 0.439
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 1701, 0.408, 868.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.126, 14.364, 0.571 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.161, 0.105
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 4214, 0.44
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 3417, 0.409, 1744.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.225, 9.235, 1.205 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.111, 0.083
#
# ... execution complete at Nov 07, 2023 10:52:59 UTC in 42.229 secs

# %%
    print("Sample Circuit:"); print(QC_ if QC_ != None else "  ... too large!")
    print("\nControlled Quantum Operator 'cQ' ="); print(cQ_ if cQ_ != None else " ... too large!")
    print("\nQuantum Operator 'Q' ="); print(Q_ if Q_ != None else " ... too large!")
    print("\nAmplitude Generator 'A' ="); print(A_ if A_ != None else " ... too large!")
    print("\nInverse QFT Circuit ="); print(QFTI_ if QC_ != None else "  ... too large!")

    # Plot metrics for all circuit sizes
    metrics.plot_metrics(f"Benchmark Results - {benchmark_name} - Qiskit")
# Out:
# Sample Circuit:
#          ┌───┐                         ┌──────┐┌──────┐┌──────┐┌──────┐ ░ »
# q1385_0: ┤ H ├─────────────────────────┤0     ├┤0     ├┤0     ├┤0     ├─░─»
#          ├───┤         ┌──────┐┌──────┐│      ││      ││      ││      │ ░ »
# q1385_1: ┤ H ├─────────┤0     ├┤0     ├┤      ├┤      ├┤      ├┤      ├─░─»
#          ├───┤ ┌──────┐│      ││      ││      ││      ││      ││      │ ░ »
# q1385_2: ┤ H ├─┤0     ├┤      ├┤      ├┤  c_Q ├┤  c_Q ├┤  c_Q ├┤  c_Q ├─░─»
#          ├───┴┐│      ││  c_Q ││  c_Q ││      ││      ││      ││      │ ░ »
# q1384_0: ┤0   ├┤1 c_Q ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├─░─»
#          │  A ││      ││      ││      ││      ││      ││      ││      │ ░ »
# q1384_1: ┤1   ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├─░─»
#          └────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘ ░ »
#   c41: 3/═════════════════════════════════════════════════════════════════»
#                                                                           »
# «         ┌──────────┐ ░ ┌─┐
# «q1385_0: ┤0         ├─░─┤M├──────
# «         │          │ ░ └╥┘┌─┐
# «q1385_1: ┤1 inv_qft ├─░──╫─┤M├───
# «         │          │ ░  ║ └╥┘┌─┐
# «q1385_2: ┤2         ├─░──╫──╫─┤M├
# «         └──────────┘ ░  ║  ║ └╥┘
# «q1384_0: ─────────────░──╫──╫──╫─
# «                      ░  ║  ║  ║
# «q1384_1: ─────────────░──╫──╫──╫─
# «                      ░  ║  ║  ║
# «  c41: 3/════════════════╩══╩══╩═
# «                         0  1  2
#
# Controlled Quantum Operator 'cQ' =
#
# q1702: ──■───
#        ┌─┴──┐
#   q_0: ┤0   ├
#        │  Q │
#   q_1: ┤1   ├
#        └────┘
#
# Quantum Operator 'Q' =
#                     ┌───────┐┌───┐          ┌───┐     ┌────┐
# q_0: ───────────────┤0      ├┤ X ├───────■──┤ X ├─────┤0   ├
#      ┌───┐┌───┐┌───┐│  A_dg │├───┤┌───┐┌─┴─┐├───┤┌───┐│  A │
# q_1: ┤ X ├┤ Z ├┤ X ├┤1      ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤1   ├
#      └───┘└───┘└───┘└───────┘└───┘└───┘└───┘└───┘└───┘└────┘
#
# Amplitude Generator 'A' =
#                              ┌───┐
# q_0: ────────────────────────┤ X ├
#      ┌────────────┐┌───┐┌───┐└─┬─┘
# q_1: ┤ Ry(2.0624) ├┤ X ├┤ X ├──■──
#      └────────────┘└───┘└───┘
#
# Inverse QFT Circuit =
#          ┌───┐                         ░                   ░       ░
# q1387_0: ┤ H ├─────■───────────■───────░───────────────────░───────░─
#          └───┘┌────┴─────┐     │       ░ ┌───┐             ░       ░
# q1387_1: ─────┤ Rz(-π/2) ├─────┼───────░─┤ H ├─────■───────░───────░─
#               └──────────┘┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# q1387_2: ─────────────────┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
#                           └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# # aer_simulator_density_matrix

# %%
def run(min_qubits=3, max_qubits=8, skip_qubits=1, max_circuits=3, num_shots=100,
        num_state_qubits=1, # default, not exposed to users
        backend_id='aer_simulator_density_matrix', provider_backend=None,
        hub="ibm-q", 
        group="open", project="main", exec_options=None,
        context=None):

    print(f"{benchmark_name} Benchmark Program - Qiskit")

    # Clamp the maximum number of qubits
    if max_qubits > MAX_QUBITS:
        print(f"INFO: {benchmark_name} benchmark is limited to a maximum of {MAX_QUBITS} qubits.")
        max_qubits = MAX_QUBITS
        
    # validate parameters (smallest circuit is 3 qubits)
    num_state_qubits = max(1, num_state_qubits)
    if max_qubits < num_state_qubits + 2:
        print(f"ERROR: AE Benchmark needs at least {num_state_qubits + 2} qubits to run")
        return
    min_qubits = max(max(3, min_qubits), num_state_qubits + 2)
    skip_qubits = max(1, skip_qubits)
    #print(f"min, max, state = {min_qubits} {max_qubits} {num_state_qubits}")

    # create context identifier
    if context is None: context = f"{benchmark_name} Benchmark"
    
    ##########
    
    # Initialize metrics module
    metrics.init_metrics()
     # Define custom result handler
    def execution_handler(qc, result, num_qubits, s_int, num_shots):

        # determine fidelity of result set
        num_counting_qubits = int(num_qubits) - num_state_qubits - 1
        counts, fidelity = analyze_and_print_result(qc, result, num_counting_qubits, int(s_int), num_shots)
        metrics.store_metric(num_qubits, s_int, 'fidelity', fidelity)

    # Initialize execution module using the execution result handler above and specified backend_id
    ex.init_execution(execution_handler)
    ex.set_execution_target(backend_id, provider_backend=provider_backend,
            hub=hub, group=group, project=project, exec_options=exec_options,
            context=context)

    ##########
    
    # Execute Benchmark Program N times for multiple circuit sizes
    # Accumulate metrics asynchronously as circuits complete
    for num_qubits in range(min_qubits, max_qubits + 1, skip_qubits):

        # reset random seed
        np.random.seed(0)
        
        # as circuit width grows, the number of counting qubits is increased
        num_counting_qubits = num_qubits - num_state_qubits - 1

        # determine number of circuits to execute for this group
        num_circuits = min(2 ** (num_counting_qubits), max_circuits)
        
        print(f"************\nExecuting [{num_circuits}] circuits with num_qubits = {num_qubits}")
        if verbose:
            print(f"              with num_state_qubits = {num_state_qubits}  num_counting_qubits = {num_counting_qubits}")
        
        # determine range of secret strings to loop over
        if 2**(num_counting_qubits) <= max_circuits:
            s_range = list(range(num_circuits))
        else:
            s_range = np.random.choice(2**(num_counting_qubits), num_circuits, False)
        
        # loop over limited # of secret strings for this
        for s_int in s_range:
            # create the circuit for given qubit size and secret string, store time metric
            ts = time.time()

            a_ = a_from_s_int(s_int, num_counting_qubits)

            qc = AmplitudeEstimation(num_state_qubits, num_counting_qubits, a_)
            metrics.store_metric(num_qubits, s_int, 'create_time', time.time() - ts)

            # collapse the 3 sub-circuit levels used in this benchmark (for qiskit)
            qc2 = qc.decompose().decompose().decompose()
            
            # submit circuit for execution on target (simulator, cloud simulator, or hardware)
            ex.submit_circuit(qc2, num_qubits, s_int, num_shots)

        # Wait for some active circuits to complete; report metrics when groups complete
        ex.throttle_execution(metrics.finalize_group)

    # Wait for all active circuits to complete; report metrics when groups complete
    ex.finalize_execution(metrics.finalize_group)
if __name__ == '__main__': run()
# Out:
# Amplitude Estimation Benchmark Program - Qiskit
# ... execution starting at Nov 07, 2023 10:53:02 UTC
# No credentials for IBMQ backend found. Using the simulator instead.
# ************
# Executing [2] circuits with num_qubits = 3
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 72, 0.422
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 58, 0.387, 29.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.019, 0.517, 0.001 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.92, 0.84
#
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 208, 0.432
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 165, 0.398, 84.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.019, 1.812, 0.026 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.839, 0.719
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 479, 0.436
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 375, 0.404, 192.667
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.028, 3.503, 0.024 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.573, 0.43
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 1017, 0.438
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 836, 0.407, 426.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.074, 6.782, 0.085 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.362, 0.289
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 2086, 0.439
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 1701, 0.408, 868.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.085, 14.53, 0.608 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.186, 0.131
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 4214, 0.44
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 3417, 0.409, 1744.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.379, 9.28, 1.245 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.102, 0.074
#
# ... execution complete at Nov 07, 2023 10:53:42 UTC in 40.037 secs

# %%
    print("Sample Circuit:"); print(QC_ if QC_ != None else "  ... too large!")
    print("\nControlled Quantum Operator 'cQ' ="); print(cQ_ if cQ_ != None else " ... too large!")
    print("\nQuantum Operator 'Q' ="); print(Q_ if Q_ != None else " ... too large!")
    print("\nAmplitude Generator 'A' ="); print(A_ if A_ != None else " ... too large!")
    print("\nInverse QFT Circuit ="); print(QFTI_ if QC_ != None else "  ... too large!")

    # Plot metrics for all circuit sizes
    metrics.plot_metrics(f"Benchmark Results - {benchmark_name} - Qiskit")
# Out:
# Sample Circuit:
#          ┌───┐                         ┌──────┐┌──────┐┌──────┐┌──────┐ ░ »
# q1984_0: ┤ H ├─────────────────────────┤0     ├┤0     ├┤0     ├┤0     ├─░─»
#          ├───┤         ┌──────┐┌──────┐│      ││      ││      ││      │ ░ »
# q1984_1: ┤ H ├─────────┤0     ├┤0     ├┤      ├┤      ├┤      ├┤      ├─░─»
#          ├───┤ ┌──────┐│      ││      ││      ││      ││      ││      │ ░ »
# q1984_2: ┤ H ├─┤0     ├┤      ├┤      ├┤  c_Q ├┤  c_Q ├┤  c_Q ├┤  c_Q ├─░─»
#          ├───┴┐│      ││  c_Q ││  c_Q ││      ││      ││      ││      │ ░ »
# q1983_0: ┤0   ├┤1 c_Q ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├─░─»
#          │  A ││      ││      ││      ││      ││      ││      ││      │ ░ »
# q1983_1: ┤1   ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├─░─»
#          └────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘ ░ »
#   c58: 3/═════════════════════════════════════════════════════════════════»
#                                                                           »
# «         ┌──────────┐ ░ ┌─┐
# «q1984_0: ┤0         ├─░─┤M├──────
# «         │          │ ░ └╥┘┌─┐
# «q1984_1: ┤1 inv_qft ├─░──╫─┤M├───
# «         │          │ ░  ║ └╥┘┌─┐
# «q1984_2: ┤2         ├─░──╫──╫─┤M├
# «         └──────────┘ ░  ║  ║ └╥┘
# «q1983_0: ─────────────░──╫──╫──╫─
# «                      ░  ║  ║  ║
# «q1983_1: ─────────────░──╫──╫──╫─
# «                      ░  ║  ║  ║
# «  c58: 3/════════════════╩══╩══╩═
# «                         0  1  2
#
# Controlled Quantum Operator 'cQ' =
#
# q2301: ──■───
#        ┌─┴──┐
#   q_0: ┤0   ├
#        │  Q │
#   q_1: ┤1   ├
#        └────┘
#
# Quantum Operator 'Q' =
#                     ┌───────┐┌───┐          ┌───┐     ┌────┐
# q_0: ───────────────┤0      ├┤ X ├───────■──┤ X ├─────┤0   ├
#      ┌───┐┌───┐┌───┐│  A_dg │├───┤┌───┐┌─┴─┐├───┤┌───┐│  A │
# q_1: ┤ X ├┤ Z ├┤ X ├┤1      ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤1   ├
#      └───┘└───┘└───┘└───────┘└───┘└───┘└───┘└───┘└───┘└────┘
#
# Amplitude Generator 'A' =
#                              ┌───┐
# q_0: ────────────────────────┤ X ├
#      ┌────────────┐┌───┐┌───┐└─┬─┘
# q_1: ┤ Ry(2.0624) ├┤ X ├┤ X ├──■──
#      └────────────┘└───┘└───┘
#
# Inverse QFT Circuit =
#          ┌───┐                         ░                   ░       ░
# q1986_0: ┤ H ├─────■───────────■───────░───────────────────░───────░─
#          └───┘┌────┴─────┐     │       ░ ┌───┐             ░       ░
# q1986_1: ─────┤ Rz(-π/2) ├─────┼───────░─┤ H ├─────■───────░───────░─
#               └──────────┘┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# q1986_2: ─────────────────┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
#                           └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# # statevector_simulator

# %%
def run(min_qubits=3, max_qubits=8, skip_qubits=1, max_circuits=3, num_shots=100,
        num_state_qubits=1, # default, not exposed to users
        backend_id='statevector_simulator', provider_backend=None,
        hub="ibm-q", 
        group="open", project="main", exec_options=None,
        context=None):

    print(f"{benchmark_name} Benchmark Program - Qiskit")

    # Clamp the maximum number of qubits
    if max_qubits > MAX_QUBITS:
        print(f"INFO: {benchmark_name} benchmark is limited to a maximum of {MAX_QUBITS} qubits.")
        max_qubits = MAX_QUBITS
        
    # validate parameters (smallest circuit is 3 qubits)
    num_state_qubits = max(1, num_state_qubits)
    if max_qubits < num_state_qubits + 2:
        print(f"ERROR: AE Benchmark needs at least {num_state_qubits + 2} qubits to run")
        return
    min_qubits = max(max(3, min_qubits), num_state_qubits + 2)
    skip_qubits = max(1, skip_qubits)
    #print(f"min, max, state = {min_qubits} {max_qubits} {num_state_qubits}")

    # create context identifier
    if context is None: context = f"{benchmark_name} Benchmark"
    
    ##########
    
    # Initialize metrics module
    metrics.init_metrics()
     # Define custom result handler
    def execution_handler(qc, result, num_qubits, s_int, num_shots):

        # determine fidelity of result set
        num_counting_qubits = int(num_qubits) - num_state_qubits - 1
        counts, fidelity = analyze_and_print_result(qc, result, num_counting_qubits, int(s_int), num_shots)
        metrics.store_metric(num_qubits, s_int, 'fidelity', fidelity)

    # Initialize execution module using the execution result handler above and specified backend_id
    ex.init_execution(execution_handler)
    ex.set_execution_target(backend_id, provider_backend=provider_backend,
            hub=hub, group=group, project=project, exec_options=exec_options,
            context=context)

    ##########
    
    # Execute Benchmark Program N times for multiple circuit sizes
    # Accumulate metrics asynchronously as circuits complete
    for num_qubits in range(min_qubits, max_qubits + 1, skip_qubits):

        # reset random seed
        np.random.seed(0)
        
        # as circuit width grows, the number of counting qubits is increased
        num_counting_qubits = num_qubits - num_state_qubits - 1

        # determine number of circuits to execute for this group
        num_circuits = min(2 ** (num_counting_qubits), max_circuits)
        
        print(f"************\nExecuting [{num_circuits}] circuits with num_qubits = {num_qubits}")
        if verbose:
            print(f"              with num_state_qubits = {num_state_qubits}  num_counting_qubits = {num_counting_qubits}")
        
        # determine range of secret strings to loop over
        if 2**(num_counting_qubits) <= max_circuits:
            s_range = list(range(num_circuits))
        else:
            s_range = np.random.choice(2**(num_counting_qubits), num_circuits, False)
        
        # loop over limited # of secret strings for this
        for s_int in s_range:
            # create the circuit for given qubit size and secret string, store time metric
            ts = time.time()

            a_ = a_from_s_int(s_int, num_counting_qubits)

            qc = AmplitudeEstimation(num_state_qubits, num_counting_qubits, a_)
            metrics.store_metric(num_qubits, s_int, 'create_time', time.time() - ts)

            # collapse the 3 sub-circuit levels used in this benchmark (for qiskit)
            qc2 = qc.decompose().decompose().decompose()
            
            # submit circuit for execution on target (simulator, cloud simulator, or hardware)
            ex.submit_circuit(qc2, num_qubits, s_int, num_shots)

        # Wait for some active circuits to complete; report metrics when groups complete
        ex.throttle_execution(metrics.finalize_group)

    # Wait for all active circuits to complete; report metrics when groups complete
    ex.finalize_execution(metrics.finalize_group)
if __name__ == '__main__': run()
# Out:
# Amplitude Estimation Benchmark Program - Qiskit
# ... execution starting at Nov 07, 2023 10:53:45 UTC
# ************
# Executing [2] circuits with num_qubits = 3
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 72, 0.422
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 58, 0.387, 29.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.017, 0.376, 0.002 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.0, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 208, 0.432
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 165, 0.398, 84.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.014, 1.496, 0.004 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.0, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 479, 0.436
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 375, 0.404, 192.667
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.021, 2.832, 0.009 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.0, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 1017, 0.438
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 836, 0.407, 426.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.035, 5.255, 0.021 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.0, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 2086, 0.439
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 1701, 0.408, 868.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.121, 9.905, 0.058 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.0, 0.0
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 4214, 0.44
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 3417, 0.409, 1744.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.134, 5.068, 0.102 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.0, 0.0
#
# ... execution complete at Nov 07, 2023 10:54:13 UTC in 28.309 secs

# %%
    print("Sample Circuit:"); print(QC_ if QC_ != None else "  ... too large!")
    print("\nControlled Quantum Operator 'cQ' ="); print(cQ_ if cQ_ != None else " ... too large!")
    print("\nQuantum Operator 'Q' ="); print(Q_ if Q_ != None else " ... too large!")
    print("\nAmplitude Generator 'A' ="); print(A_ if A_ != None else " ... too large!")
    print("\nInverse QFT Circuit ="); print(QFTI_ if QC_ != None else "  ... too large!")

    # Plot metrics for all circuit sizes
    metrics.plot_metrics(f"Benchmark Results - {benchmark_name} - Qiskit")
# Out:
# Sample Circuit:
#          ┌───┐                         ┌──────┐┌──────┐┌──────┐┌──────┐ ░ »
# q2548_0: ┤ H ├─────────────────────────┤0     ├┤0     ├┤0     ├┤0     ├─░─»
#          ├───┤         ┌──────┐┌──────┐│      ││      ││      ││      │ ░ »
# q2548_1: ┤ H ├─────────┤0     ├┤0     ├┤      ├┤      ├┤      ├┤      ├─░─»
#          ├───┤ ┌──────┐│      ││      ││      ││      ││      ││      │ ░ »
# q2548_2: ┤ H ├─┤0     ├┤      ├┤      ├┤  c_Q ├┤  c_Q ├┤  c_Q ├┤  c_Q ├─░─»
#          ├───┴┐│      ││  c_Q ││  c_Q ││      ││      ││      ││      │ ░ »
# q2547_0: ┤0   ├┤1 c_Q ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├─░─»
#          │  A ││      ││      ││      ││      ││      ││      ││      │ ░ »
# q2547_1: ┤1   ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├─░─»
#          └────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘ ░ »
#   c75: 3/═════════════════════════════════════════════════════════════════»
#                                                                           »
# «         ┌──────────┐ ░ ┌─┐
# «q2548_0: ┤0         ├─░─┤M├──────
# «         │          │ ░ └╥┘┌─┐
# «q2548_1: ┤1 inv_qft ├─░──╫─┤M├───
# «         │          │ ░  ║ └╥┘┌─┐
# «q2548_2: ┤2         ├─░──╫──╫─┤M├
# «         └──────────┘ ░  ║  ║ └╥┘
# «q2547_0: ─────────────░──╫──╫──╫─
# «                      ░  ║  ║  ║
# «q2547_1: ─────────────░──╫──╫──╫─
# «                      ░  ║  ║  ║
# «  c75: 3/════════════════╩══╩══╩═
# «                         0  1  2
#
# Controlled Quantum Operator 'cQ' =
#
# q2802: ──■───
#        ┌─┴──┐
#   q_0: ┤0   ├
#        │  Q │
#   q_1: ┤1   ├
#        └────┘
#
# Quantum Operator 'Q' =
#                     ┌───────┐┌───┐          ┌───┐     ┌────┐
# q_0: ───────────────┤0      ├┤ X ├───────■──┤ X ├─────┤0   ├
#      ┌───┐┌───┐┌───┐│  A_dg │├───┤┌───┐┌─┴─┐├───┤┌───┐│  A │
# q_1: ┤ X ├┤ Z ├┤ X ├┤1      ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤1   ├
#      └───┘└───┘└───┘└───────┘└───┘└───┘└───┘└───┘└───┘└────┘
#
# Amplitude Generator 'A' =
#                              ┌───┐
# q_0: ────────────────────────┤ X ├
#      ┌────────────┐┌───┐┌───┐└─┬─┘
# q_1: ┤ Ry(2.0624) ├┤ X ├┤ X ├──■──
#      └────────────┘└───┘└───┘
#
# Inverse QFT Circuit =
#          ┌───┐                         ░                   ░       ░
# q2550_0: ┤ H ├─────■───────────■───────░───────────────────░───────░─
#          └───┘┌────┴─────┐     │       ░ ┌───┐             ░       ░
# q2550_1: ─────┤ Rz(-π/2) ├─────┼───────░─┤ H ├─────■───────░───────░─
#               └──────────┘┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# q2550_2: ─────────────────┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
#                           └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# # pulse_simulator

# %%
def run(min_qubits=3, max_qubits=8, skip_qubits=1, max_circuits=3, num_shots=100,
        num_state_qubits=1, # default, not exposed to users
        backend_id='pulse_simulator', provider_backend=None,
        hub="ibm-q", 
        group="open", project="main", exec_options=None,
        context=None):

    print(f"{benchmark_name} Benchmark Program - Qiskit")

    # Clamp the maximum number of qubits
    if max_qubits > MAX_QUBITS:
        print(f"INFO: {benchmark_name} benchmark is limited to a maximum of {MAX_QUBITS} qubits.")
        max_qubits = MAX_QUBITS
        
    # validate parameters (smallest circuit is 3 qubits)
    num_state_qubits = max(1, num_state_qubits)
    if max_qubits < num_state_qubits + 2:
        print(f"ERROR: AE Benchmark needs at least {num_state_qubits + 2} qubits to run")
        return
    min_qubits = max(max(3, min_qubits), num_state_qubits + 2)
    skip_qubits = max(1, skip_qubits)
    #print(f"min, max, state = {min_qubits} {max_qubits} {num_state_qubits}")

    # create context identifier
    if context is None: context = f"{benchmark_name} Benchmark"
    
    ##########
    
    # Initialize metrics module
    metrics.init_metrics()
     # Define custom result handler
    def execution_handler(qc, result, num_qubits, s_int, num_shots):

        # determine fidelity of result set
        num_counting_qubits = int(num_qubits) - num_state_qubits - 1
        counts, fidelity = analyze_and_print_result(qc, result, num_counting_qubits, int(s_int), num_shots)
        metrics.store_metric(num_qubits, s_int, 'fidelity', fidelity)

    # Initialize execution module using the execution result handler above and specified backend_id
    ex.init_execution(execution_handler)
    ex.set_execution_target(backend_id, provider_backend=provider_backend,
            hub=hub, group=group, project=project, exec_options=exec_options,
            context=context)

    ##########
    
    # Execute Benchmark Program N times for multiple circuit sizes
    # Accumulate metrics asynchronously as circuits complete
    for num_qubits in range(min_qubits, max_qubits + 1, skip_qubits):

        # reset random seed
        np.random.seed(0)
        
        # as circuit width grows, the number of counting qubits is increased
        num_counting_qubits = num_qubits - num_state_qubits - 1

        # determine number of circuits to execute for this group
        num_circuits = min(2 ** (num_counting_qubits), max_circuits)
        
        print(f"************\nExecuting [{num_circuits}] circuits with num_qubits = {num_qubits}")
        if verbose:
            print(f"              with num_state_qubits = {num_state_qubits}  num_counting_qubits = {num_counting_qubits}")
        
        # determine range of secret strings to loop over
        if 2**(num_counting_qubits) <= max_circuits:
            s_range = list(range(num_circuits))
        else:
            s_range = np.random.choice(2**(num_counting_qubits), num_circuits, False)
        
        # loop over limited # of secret strings for this
        for s_int in s_range:
            # create the circuit for given qubit size and secret string, store time metric
            ts = time.time()

            a_ = a_from_s_int(s_int, num_counting_qubits)

            qc = AmplitudeEstimation(num_state_qubits, num_counting_qubits, a_)
            metrics.store_metric(num_qubits, s_int, 'create_time', time.time() - ts)

            # collapse the 3 sub-circuit levels used in this benchmark (for qiskit)
            qc2 = qc.decompose().decompose().decompose()
            
            # submit circuit for execution on target (simulator, cloud simulator, or hardware)
            ex.submit_circuit(qc2, num_qubits, s_int, num_shots)

        # Wait for some active circuits to complete; report metrics when groups complete
        ex.throttle_execution(metrics.finalize_group)

    # Wait for all active circuits to complete; report metrics when groups complete
    ex.finalize_execution(metrics.finalize_group)
if __name__ == '__main__': run()
# Out:
# Amplitude Estimation Benchmark Program - Qiskit
# ... execution starting at Nov 07, 2023 10:54:16 UTC
# No credentials for IBMQ backend found. Using the simulator instead.
# ************
# Executing [2] circuits with num_qubits = 3
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 72, 0.422
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 58, 0.387, 29.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.007, 0.36, 0.002 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.0, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 208, 0.432
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 165, 0.398, 84.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.02, 1.504, 0.004 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.0, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 479, 0.436
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 375, 0.404, 192.667
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.024, 2.855, 0.025 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.0, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 1017, 0.438
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 836, 0.407, 426.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.033, 5.123, 0.04 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.0, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 2086, 0.439
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 1701, 0.408, 868.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.076, 9.891, 0.054 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.0, 0.0
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 4214, 0.44
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 3417, 0.409, 1744.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.174, 5.077, 0.099 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.0, 0.0
#
# ... execution complete at Nov 07, 2023 10:54:44 UTC in 28.152 secs

# %%
    print("Sample Circuit:"); print(QC_ if QC_ != None else "  ... too large!")
    print("\nControlled Quantum Operator 'cQ' ="); print(cQ_ if cQ_ != None else " ... too large!")
    print("\nQuantum Operator 'Q' ="); print(Q_ if Q_ != None else " ... too large!")
    print("\nAmplitude Generator 'A' ="); print(A_ if A_ != None else " ... too large!")
    print("\nInverse QFT Circuit ="); print(QFTI_ if QC_ != None else "  ... too large!")

    # Plot metrics for all circuit sizes
    metrics.plot_metrics(f"Benchmark Results - {benchmark_name} - Qiskit")
# Out:
# Sample Circuit:
#          ┌───┐                         ┌──────┐┌──────┐┌──────┐┌──────┐ ░ »
# q3028_0: ┤ H ├─────────────────────────┤0     ├┤0     ├┤0     ├┤0     ├─░─»
#          ├───┤         ┌──────┐┌──────┐│      ││      ││      ││      │ ░ »
# q3028_1: ┤ H ├─────────┤0     ├┤0     ├┤      ├┤      ├┤      ├┤      ├─░─»
#          ├───┤ ┌──────┐│      ││      ││      ││      ││      ││      │ ░ »
# q3028_2: ┤ H ├─┤0     ├┤      ├┤      ├┤  c_Q ├┤  c_Q ├┤  c_Q ├┤  c_Q ├─░─»
#          ├───┴┐│      ││  c_Q ││  c_Q ││      ││      ││      ││      │ ░ »
# q3027_0: ┤0   ├┤1 c_Q ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├─░─»
#          │  A ││      ││      ││      ││      ││      ││      ││      │ ░ »
# q3027_1: ┤1   ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├─░─»
#          └────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘ ░ »
#   c92: 3/═════════════════════════════════════════════════════════════════»
#                                                                           »
# «         ┌──────────┐ ░ ┌─┐
# «q3028_0: ┤0         ├─░─┤M├──────
# «         │          │ ░ └╥┘┌─┐
# «q3028_1: ┤1 inv_qft ├─░──╫─┤M├───
# «         │          │ ░  ║ └╥┘┌─┐
# «q3028_2: ┤2         ├─░──╫──╫─┤M├
# «         └──────────┘ ░  ║  ║ └╥┘
# «q3027_0: ─────────────░──╫──╫──╫─
# «                      ░  ║  ║  ║
# «q3027_1: ─────────────░──╫──╫──╫─
# «                      ░  ║  ║  ║
# «  c92: 3/════════════════╩══╩══╩═
# «                         0  1  2
#
# Controlled Quantum Operator 'cQ' =
#
# q3282: ──■───
#        ┌─┴──┐
#   q_0: ┤0   ├
#        │  Q │
#   q_1: ┤1   ├
#        └────┘
#
# Quantum Operator 'Q' =
#                     ┌───────┐┌───┐          ┌───┐     ┌────┐
# q_0: ───────────────┤0      ├┤ X ├───────■──┤ X ├─────┤0   ├
#      ┌───┐┌───┐┌───┐│  A_dg │├───┤┌───┐┌─┴─┐├───┤┌───┐│  A │
# q_1: ┤ X ├┤ Z ├┤ X ├┤1      ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤1   ├
#      └───┘└───┘└───┘└───────┘└───┘└───┘└───┘└───┘└───┘└────┘
#
# Amplitude Generator 'A' =
#                              ┌───┐
# q_0: ────────────────────────┤ X ├
#      ┌────────────┐┌───┐┌───┐└─┬─┘
# q_1: ┤ Ry(2.0624) ├┤ X ├┤ X ├──■──
#      └────────────┘└───┘└───┘
#
# Inverse QFT Circuit =
#          ┌───┐                         ░                   ░       ░
# q3030_0: ┤ H ├─────■───────────■───────░───────────────────░───────░─
#          └───┘┌────┴─────┐     │       ░ ┌───┐             ░       ░
# q3030_1: ─────┤ Rz(-π/2) ├─────┼───────░─┤ H ├─────■───────░───────░─
#               └──────────┘┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# q3030_2: ─────────────────┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
#                           └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# # aer_simulator_matrix_product_state

# %%
def run(min_qubits=3, max_qubits=8, skip_qubits=1, max_circuits=3, num_shots=100,
        num_state_qubits=1, # default, not exposed to users
        backend_id='pulse_simulator', provider_backend=None,
        hub="ibm-q", 
        group="open", project="main", exec_options=None,
        context=None):

    print(f"{benchmark_name} Benchmark Program - Qiskit")

    # Clamp the maximum number of qubits
    if max_qubits > MAX_QUBITS:
        print(f"INFO: {benchmark_name} benchmark is limited to a maximum of {MAX_QUBITS} qubits.")
        max_qubits = MAX_QUBITS
        
    # validate parameters (smallest circuit is 3 qubits)
    num_state_qubits = max(1, num_state_qubits)
    if max_qubits < num_state_qubits + 2:
        print(f"ERROR: AE Benchmark needs at least {num_state_qubits + 2} qubits to run")
        return
    min_qubits = max(max(3, min_qubits), num_state_qubits + 2)
    skip_qubits = max(1, skip_qubits)
    #print(f"min, max, state = {min_qubits} {max_qubits} {num_state_qubits}")

    # create context identifier
    if context is None: context = f"{benchmark_name} Benchmark"
    
    ##########
    
    # Initialize metrics module
    metrics.init_metrics()
     # Define custom result handler
    def execution_handler(qc, result, num_qubits, s_int, num_shots):

        # determine fidelity of result set
        num_counting_qubits = int(num_qubits) - num_state_qubits - 1
        counts, fidelity = analyze_and_print_result(qc, result, num_counting_qubits, int(s_int), num_shots)
        metrics.store_metric(num_qubits, s_int, 'fidelity', fidelity)

    # Initialize execution module using the execution result handler above and specified backend_id
    ex.init_execution(execution_handler)
    ex.set_execution_target(backend_id, provider_backend=provider_backend,
            hub=hub, group=group, project=project, exec_options=exec_options,
            context=context)

    ##########
    
    # Execute Benchmark Program N times for multiple circuit sizes
    # Accumulate metrics asynchronously as circuits complete
    for num_qubits in range(min_qubits, max_qubits + 1, skip_qubits):

        # reset random seed
        np.random.seed(0)
        
        # as circuit width grows, the number of counting qubits is increased
        num_counting_qubits = num_qubits - num_state_qubits - 1

        # determine number of circuits to execute for this group
        num_circuits = min(2 ** (num_counting_qubits), max_circuits)
        
        print(f"************\nExecuting [{num_circuits}] circuits with num_qubits = {num_qubits}")
        if verbose:
            print(f"              with num_state_qubits = {num_state_qubits}  num_counting_qubits = {num_counting_qubits}")
        
        # determine range of secret strings to loop over
        if 2**(num_counting_qubits) <= max_circuits:
            s_range = list(range(num_circuits))
        else:
            s_range = np.random.choice(2**(num_counting_qubits), num_circuits, False)
        
        # loop over limited # of secret strings for this
        for s_int in s_range:
            # create the circuit for given qubit size and secret string, store time metric
            ts = time.time()

            a_ = a_from_s_int(s_int, num_counting_qubits)

            qc = AmplitudeEstimation(num_state_qubits, num_counting_qubits, a_)
            metrics.store_metric(num_qubits, s_int, 'create_time', time.time() - ts)

            # collapse the 3 sub-circuit levels used in this benchmark (for qiskit)
            qc2 = qc.decompose().decompose().decompose()
            
            # submit circuit for execution on target (simulator, cloud simulator, or hardware)
            ex.submit_circuit(qc2, num_qubits, s_int, num_shots)

        # Wait for some active circuits to complete; report metrics when groups complete
        ex.throttle_execution(metrics.finalize_group)

    # Wait for all active circuits to complete; report metrics when groups complete
    ex.finalize_execution(metrics.finalize_group)
if __name__ == '__main__': run()
# Out:
# Amplitude Estimation Benchmark Program - Qiskit
# ... execution starting at Nov 07, 2023 10:54:47 UTC
# No credentials for IBMQ backend found. Using the simulator instead.
# ************
# Executing [2] circuits with num_qubits = 3
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 72, 0.422
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 58, 0.387, 29.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.02, 0.37, 0.003 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.0, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 208, 0.432
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 165, 0.398, 84.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.023, 1.49, 0.002 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.0, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 479, 0.436
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 375, 0.404, 192.667
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.023, 2.83, 0.003 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.0, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 1017, 0.438
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 836, 0.407, 426.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.067, 5.133, 0.033 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.0, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 2086, 0.439
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 1701, 0.408, 868.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.073, 9.937, 0.067 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.0, 0.0
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 4214, 0.44
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 3417, 0.409, 1744.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.185, 5.144, 0.097 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.0, 0.0
#
# ... execution complete at Nov 07, 2023 10:55:16 UTC in 28.188 secs

# %%
    print("Sample Circuit:"); print(QC_ if QC_ != None else "  ... too large!")
    print("\nControlled Quantum Operator 'cQ' ="); print(cQ_ if cQ_ != None else " ... too large!")
    print("\nQuantum Operator 'Q' ="); print(Q_ if Q_ != None else " ... too large!")
    print("\nAmplitude Generator 'A' ="); print(A_ if A_ != None else " ... too large!")
    print("\nInverse QFT Circuit ="); print(QFTI_ if QC_ != None else "  ... too large!")

    # Plot metrics for all circuit sizes
    metrics.plot_metrics(f"Benchmark Results - {benchmark_name} - Qiskit")
# Out:
# Sample Circuit:
#          ┌───┐                         ┌──────┐┌──────┐┌──────┐┌──────┐ ░ »
# q3508_0: ┤ H ├─────────────────────────┤0     ├┤0     ├┤0     ├┤0     ├─░─»
#          ├───┤         ┌──────┐┌──────┐│      ││      ││      ││      │ ░ »
# q3508_1: ┤ H ├─────────┤0     ├┤0     ├┤      ├┤      ├┤      ├┤      ├─░─»
#          ├───┤ ┌──────┐│      ││      ││      ││      ││      ││      │ ░ »
# q3508_2: ┤ H ├─┤0     ├┤      ├┤      ├┤  c_Q ├┤  c_Q ├┤  c_Q ├┤  c_Q ├─░─»
#          ├───┴┐│      ││  c_Q ││  c_Q ││      ││      ││      ││      │ ░ »
# q3507_0: ┤0   ├┤1 c_Q ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├─░─»
#          │  A ││      ││      ││      ││      ││      ││      ││      │ ░ »
# q3507_1: ┤1   ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├─░─»
#          └────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘ ░ »
#  c109: 3/═════════════════════════════════════════════════════════════════»
#                                                                           »
# «         ┌──────────┐ ░ ┌─┐
# «q3508_0: ┤0         ├─░─┤M├──────
# «         │          │ ░ └╥┘┌─┐
# «q3508_1: ┤1 inv_qft ├─░──╫─┤M├───
# «         │          │ ░  ║ └╥┘┌─┐
# «q3508_2: ┤2         ├─░──╫──╫─┤M├
# «         └──────────┘ ░  ║  ║ └╥┘
# «q3507_0: ─────────────░──╫──╫──╫─
# «                      ░  ║  ║  ║
# «q3507_1: ─────────────░──╫──╫──╫─
# «                      ░  ║  ║  ║
# « c109: 3/════════════════╩══╩══╩═
# «                         0  1  2
#
# Controlled Quantum Operator 'cQ' =
#
# q3762: ──■───
#        ┌─┴──┐
#   q_0: ┤0   ├
#        │  Q │
#   q_1: ┤1   ├
#        └────┘
#
# Quantum Operator 'Q' =
#                     ┌───────┐┌───┐          ┌───┐     ┌────┐
# q_0: ───────────────┤0      ├┤ X ├───────■──┤ X ├─────┤0   ├
#      ┌───┐┌───┐┌───┐│  A_dg │├───┤┌───┐┌─┴─┐├───┤┌───┐│  A │
# q_1: ┤ X ├┤ Z ├┤ X ├┤1      ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤1   ├
#      └───┘└───┘└───┘└───────┘└───┘└───┘└───┘└───┘└───┘└────┘
#
# Amplitude Generator 'A' =
#                              ┌───┐
# q_0: ────────────────────────┤ X ├
#      ┌────────────┐┌───┐┌───┐└─┬─┘
# q_1: ┤ Ry(2.0624) ├┤ X ├┤ X ├──■──
#      └────────────┘└───┘└───┘
#
# Inverse QFT Circuit =
#          ┌───┐                         ░                   ░       ░
# q3510_0: ┤ H ├─────■───────────■───────░───────────────────░───────░─
#          └───┘┌────┴─────┐     │       ░ ┌───┐             ░       ░
# q3510_1: ─────┤ Rz(-π/2) ├─────┼───────░─┤ H ├─────■───────░───────░─
#               └──────────┘┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# q3510_2: ─────────────────┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
#                           └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# # unitary_simulator

# %%
def run(min_qubits=3, max_qubits=8, skip_qubits=1, max_circuits=3, num_shots=100,
        num_state_qubits=1, # default, not exposed to users
        backend_id='unitary_simulator', provider_backend=None,
        hub="ibm-q", 
        group="open", project="main", exec_options=None,
        context=None):

    print(f"{benchmark_name} Benchmark Program - Qiskit")

    # Clamp the maximum number of qubits
    if max_qubits > MAX_QUBITS:
        print(f"INFO: {benchmark_name} benchmark is limited to a maximum of {MAX_QUBITS} qubits.")
        max_qubits = MAX_QUBITS
        
    # validate parameters (smallest circuit is 3 qubits)
    num_state_qubits = max(1, num_state_qubits)
    if max_qubits < num_state_qubits + 2:
        print(f"ERROR: AE Benchmark needs at least {num_state_qubits + 2} qubits to run")
        return
    min_qubits = max(max(3, min_qubits), num_state_qubits + 2)
    skip_qubits = max(1, skip_qubits)
    #print(f"min, max, state = {min_qubits} {max_qubits} {num_state_qubits}")

    # create context identifier
    if context is None: context = f"{benchmark_name} Benchmark"
    
    ##########
    
    # Initialize metrics module
    metrics.init_metrics()
     # Define custom result handler
    def execution_handler(qc, result, num_qubits, s_int, num_shots):

        # determine fidelity of result set
        num_counting_qubits = int(num_qubits) - num_state_qubits - 1
        counts, fidelity = analyze_and_print_result(qc, result, num_counting_qubits, int(s_int), num_shots)
        metrics.store_metric(num_qubits, s_int, 'fidelity', fidelity)

    # Initialize execution module using the execution result handler above and specified backend_id
    ex.init_execution(execution_handler)
    ex.set_execution_target(backend_id, provider_backend=provider_backend,
            hub=hub, group=group, project=project, exec_options=exec_options,
            context=context)

    ##########
    
    # Execute Benchmark Program N times for multiple circuit sizes
    # Accumulate metrics asynchronously as circuits complete
    for num_qubits in range(min_qubits, max_qubits + 1, skip_qubits):

        # reset random seed
        np.random.seed(0)
        
        # as circuit width grows, the number of counting qubits is increased
        num_counting_qubits = num_qubits - num_state_qubits - 1

        # determine number of circuits to execute for this group
        num_circuits = min(2 ** (num_counting_qubits), max_circuits)
        
        print(f"************\nExecuting [{num_circuits}] circuits with num_qubits = {num_qubits}")
        if verbose:
            print(f"              with num_state_qubits = {num_state_qubits}  num_counting_qubits = {num_counting_qubits}")
        
        # determine range of secret strings to loop over
        if 2**(num_counting_qubits) <= max_circuits:
            s_range = list(range(num_circuits))
        else:
            s_range = np.random.choice(2**(num_counting_qubits), num_circuits, False)
        
        # loop over limited # of secret strings for this
        for s_int in s_range:
            # create the circuit for given qubit size and secret string, store time metric
            ts = time.time()

            a_ = a_from_s_int(s_int, num_counting_qubits)

            qc = AmplitudeEstimation(num_state_qubits, num_counting_qubits, a_)
            metrics.store_metric(num_qubits, s_int, 'create_time', time.time() - ts)

            # collapse the 3 sub-circuit levels used in this benchmark (for qiskit)
            qc2 = qc.decompose().decompose().decompose()
            
            # submit circuit for execution on target (simulator, cloud simulator, or hardware)
            ex.submit_circuit(qc2, num_qubits, s_int, num_shots)

        # Wait for some active circuits to complete; report metrics when groups complete
        ex.throttle_execution(metrics.finalize_group)

    # Wait for all active circuits to complete; report metrics when groups complete
    ex.finalize_execution(metrics.finalize_group)
if __name__ == '__main__': run()
# Out:
# Amplitude Estimation Benchmark Program - Qiskit
# ... execution starting at Nov 07, 2023 11:54:09 UTC
# No credentials for IBMQ backend found. Using the simulator instead.
# ************
# Executing [2] circuits with num_qubits = 3
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 72, 0.422
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 58, 0.387, 29.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.019, 0.369, 0.002 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.0, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 208, 0.432
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 165, 0.398, 84.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.01, 1.516, 0.019 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.0, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 479, 0.436
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 375, 0.404, 192.667
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.028, 2.907, 0.011 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.0, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 1017, 0.438
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 836, 0.407, 426.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.047, 5.259, 0.026 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.0, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 2086, 0.439
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 1701, 0.408, 868.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.07, 10.19, 0.055 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.0, 0.0
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 4214, 0.44
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 3417, 0.409, 1744.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.173, 5.406, 0.102 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.0, 0.0
#
# ... execution complete at Nov 07, 2023 11:54:38 UTC in 29.15 secs

# %%
    print("Sample Circuit:"); print(QC_ if QC_ != None else "  ... too large!")
    print("\nControlled Quantum Operator 'cQ' ="); print(cQ_ if cQ_ != None else " ... too large!")
    print("\nQuantum Operator 'Q' ="); print(Q_ if Q_ != None else " ... too large!")
    print("\nAmplitude Generator 'A' ="); print(A_ if A_ != None else " ... too large!")
    print("\nInverse QFT Circuit ="); print(QFTI_ if QC_ != None else "  ... too large!")

    # Plot metrics for all circuit sizes
    metrics.plot_metrics(f"Benchmark Results - {benchmark_name} - Qiskit")
# Out:
# Sample Circuit:
#          ┌───┐                         ┌──────┐┌──────┐┌──────┐┌──────┐ ░ »
# q3988_0: ┤ H ├─────────────────────────┤0     ├┤0     ├┤0     ├┤0     ├─░─»
#          ├───┤         ┌──────┐┌──────┐│      ││      ││      ││      │ ░ »
# q3988_1: ┤ H ├─────────┤0     ├┤0     ├┤      ├┤      ├┤      ├┤      ├─░─»
#          ├───┤ ┌──────┐│      ││      ││      ││      ││      ││      │ ░ »
# q3988_2: ┤ H ├─┤0     ├┤      ├┤      ├┤  c_Q ├┤  c_Q ├┤  c_Q ├┤  c_Q ├─░─»
#          ├───┴┐│      ││  c_Q ││  c_Q ││      ││      ││      ││      │ ░ »
# q3987_0: ┤0   ├┤1 c_Q ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├─░─»
#          │  A ││      ││      ││      ││      ││      ││      ││      │ ░ »
# q3987_1: ┤1   ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├─░─»
#          └────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘ ░ »
#  c126: 3/═════════════════════════════════════════════════════════════════»
#                                                                           »
# «         ┌──────────┐ ░ ┌─┐
# «q3988_0: ┤0         ├─░─┤M├──────
# «         │          │ ░ └╥┘┌─┐
# «q3988_1: ┤1 inv_qft ├─░──╫─┤M├───
# «         │          │ ░  ║ └╥┘┌─┐
# «q3988_2: ┤2         ├─░──╫──╫─┤M├
# «         └──────────┘ ░  ║  ║ └╥┘
# «q3987_0: ─────────────░──╫──╫──╫─
# «                      ░  ║  ║  ║
# «q3987_1: ─────────────░──╫──╫──╫─
# «                      ░  ║  ║  ║
# « c126: 3/════════════════╩══╩══╩═
# «                         0  1  2
#
# Controlled Quantum Operator 'cQ' =
#
# q4242: ──■───
#        ┌─┴──┐
#   q_0: ┤0   ├
#        │  Q │
#   q_1: ┤1   ├
#        └────┘
#
# Quantum Operator 'Q' =
#                     ┌───────┐┌───┐          ┌───┐     ┌────┐
# q_0: ───────────────┤0      ├┤ X ├───────■──┤ X ├─────┤0   ├
#      ┌───┐┌───┐┌───┐│  A_dg │├───┤┌───┐┌─┴─┐├───┤┌───┐│  A │
# q_1: ┤ X ├┤ Z ├┤ X ├┤1      ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤1   ├
#      └───┘└───┘└───┘└───────┘└───┘└───┘└───┘└───┘└───┘└────┘
#
# Amplitude Generator 'A' =
#                              ┌───┐
# q_0: ────────────────────────┤ X ├
#      ┌────────────┐┌───┐┌───┐└─┬─┘
# q_1: ┤ Ry(2.0624) ├┤ X ├┤ X ├──■──
#      └────────────┘└───┘└───┘
#
# Inverse QFT Circuit =
#          ┌───┐                         ░                   ░       ░
# q3990_0: ┤ H ├─────■───────────■───────░───────────────────░───────░─
#          └───┘┌────┴─────┐     │       ░ ┌───┐             ░       ░
# q3990_1: ─────┤ Rz(-π/2) ├─────┼───────░─┤ H ├─────■───────░───────░─
#               └──────────┘┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# q3990_2: ─────────────────┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
#                           └──────────┘ ░      └──────────┘ ░ └───┘ ░
